# %%
# Dependencies and Setup
import pandas as pd

# Input files to load
offense_file_to_load = "Resources/nfl_statistics_team_offense_by_season.csv"
defense_file_to_load = "Resources/nfl_statistics_team_defense_by_season.csv"
playoff_file_to_load = "Resources/nfl_playoff_results_by_season.csv"

# Read offense, oefense, and playoffs into DataFrames
offense_df = pd.read_csv(offense_file_to_load)
defense_df = pd.read_csv(defense_file_to_load)
playoff_df = pd.read_csv(playoff_file_to_load)

# %%
offense_df.head()
# Out:
#    Season  OffRank                 Team  GamesPlayed  OffTotPoints  \
# 0    2022        1   Kansas City Chiefs           17           496
# 1    2022        2  Philadelphia Eagles           17           477
# 2    2022        3       Dallas Cowboys           17           467
# 3    2022        4        Buffalo Bills           16           455
# 4    2022        5        Detroit Lions           17           453
#
#    OffTotYards  OffTotPlaysRun  OffTotYardsPerPlay  OffTotTurnovers  \
# 0         7032            1094                 6.4               23
# 1         6614            1124                 5.9               19
# 2         6034            1114                 5.4               23
# 3         6361            1037                 6.1               27
# 4         6460            1092                 5.9               15
#
#    OffTotFumbles  ...  OffRushYards  OffRushTouchdowns  \
# 0             11  ...          1970                 18
# 1             10  ...          2509                 32
# 2              5  ...          2298                 24
# 3             13  ...          2232                 15
# 4              8  ...          2179                 23
#
#    OffRushYardsPerAttempt  OffRush1stDowns  OffNumOfPenalties  \
# 0                     4.7              105                 87
# 1                     4.6              161                 90
# 2                     4.3              129                104
# 3                     5.2              128                 92
# 4                     4.5              114                 90
#
#    OffPenaltyYards  Off1stDownsByPenalty  OffPctOfDrivesEndingInScore  \
# 0              838                    31                         46.4
# 1              682                    29                         42.5
# 2              842                    24                         41.5
# 3              709                    27                         45.0
# 4              773                    34                         43.2
#
#    OffPctOfDrivesEndingInTurnover  OffExpectedPointsContributed
# 0                            10.1                        261.80
# 1                            10.2                        210.87
# 2                            10.8                        112.34
# 3                            15.2                        157.46
# 4                             8.0                        162.04
#
# [5 rows x 29 columns]

# %%
defense_df.head()
# Out:
#    Season  DefRank                 Team  GamesPlayed  DefTotPoints  \
# 0    2022        1  San Francisco 49ers           17           277
# 1    2022        2        Buffalo Bills           16           286
# 2    2022        3     Baltimore Ravens           17           315
# 3    2022        4        New York Jets           17           316
# 4    2022        5   Cincinnati Bengals           16           322
#
#    DefTotYards  DefTotPlaysRun  DefTotYardsPerPlay  DefTotTakeaways  \
# 0         5110            1026                 5.0               30
# 1         5106             997                 5.1               27
# 2         5513            1047                 5.3               25
# 3         5288            1093                 4.8               16
# 4         5371             996                 5.4               24
#
#    DefTotFumbles  ...  DefRushYards  DefRushTouchdowns  \
# 0             10  ...          1321                 11
# 1             10  ...          1673                 10
# 2             11  ...          1566                 11
# 3              4  ...          2068                 14
# 4             11  ...          1706                 12
#
#    DefRushYardsPerAttempt  DefRush1stDowns  DefNumOfPenalties  \
# 0                     3.4               77                 96
# 1                     4.3              103                 89
# 2                     3.9               91                 79
# 3                     4.2              117                 90
# 4                     4.2              102                100
#
#    DefPenaltyYards  Def1stDownsByPenalty  DefPctOfDrivesEndingInScore  \
# 0              832                    26                         25.7
# 1              754                    29                         31.0
# 2              650                    26                         35.8
# 3              707                    27                         32.3
# 4              832                    20                         36.4
#
#    DefPctOfDrivesEndingInTurnover  DefExpectedPointsContributed
# 0                            15.3                         56.26
# 1                            14.3                          4.46
# 2                            13.9                        -32.38
# 3                             8.3                         25.96
# 4                            13.1                        -20.02
#
# [5 rows x 29 columns]

# %%
playoff_df.head()
# Out:
#    Season  RoundNum RoundName  Day       Date                Winner  \
# 0    2022         1  WildCard  Sat  1/14/2023  Jacksonville Jaguars
# 1    2022         1  WildCard  Sat  1/14/2023   San Francisco 49ers
# 2    2022         1  WildCard  Sun  1/15/2023         Buffalo Bills
# 3    2022         1  WildCard  Sun  1/15/2023    Cincinnati Bengals
# 4    2022         1  WildCard  Sun  1/15/2023       New York Giants
#
#   Unnamed: 6                 Loser Unnamed: 8  PtsWinner  PtsLoser
# 0        NaN  Los Angeles Chargers   boxscore         31        30
# 1        NaN      Seattle Seahawks   boxscore         41        23
# 2        NaN        Miami Dolphins   boxscore         34        31
# 3        NaN      Baltimore Ravens   boxscore         24        17
# 4          @     Minnesota Vikings   boxscore         31        24

# %%
# Merge offense and defense into 1 df
reg_season_df = pd.merge(offense_df, defense_df, on=["Season", "Team"])
reg_season_df.head()
# Out:
#    Season  OffRank                 Team  GamesPlayed_x  OffTotPoints  \
# 0    2022        1   Kansas City Chiefs             17           496
# 1    2022        2  Philadelphia Eagles             17           477
# 2    2022        3       Dallas Cowboys             17           467
# 3    2022        4        Buffalo Bills             16           455
# 4    2022        5        Detroit Lions             17           453
#
#    OffTotYards  OffTotPlaysRun  OffTotYardsPerPlay  OffTotTurnovers  \
# 0         7032            1094                 6.4               23
# 1         6614            1124                 5.9               19
# 2         6034            1114                 5.4               23
# 3         6361            1037                 6.1               27
# 4         6460            1092                 5.9               15
#
#    OffTotFumbles  ...  DefRushYards  DefRushTouchdowns  \
# 0             11  ...          1823                 10
# 1             10  ...          2068                 15
# 2              5  ...          2198                  9
# 3             13  ...          1673                 10
# 4              8  ...          2491                 22
#
#    DefRushYardsPerAttempt  DefRush1stDowns  DefNumOfPenalties  \
# 0                     4.4              102                 98
# 1                     4.6              115                 95
# 2                     4.4              119                 98
# 3                     4.3              103                 89
# 4                     5.2              135                103
#
#    DefPenaltyYards  Def1stDownsByPenalty  DefPctOfDrivesEndingInScore  \
# 0              734                    28                         35.9
# 1              798                    24                         32.4
# 2              851                    34                         33.5
# 3              754                    29                         31.0
# 4              818                    33                         41.2
#
#    DefPctOfDrivesEndingInTurnover  DefExpectedPointsContributed
# 0                            10.3                        -49.50
# 1                            15.1                         39.93
# 2                            16.2                         31.77
# 3                            14.3                          4.46
# 4                            11.9                       -159.66
#
# [5 rows x 56 columns]

# %%
reg_point_df = reg_season_df

merged_points_df = pd.merge(playoff_df, reg_point_df, left_on=["Season", "Winner"], right_on=["Season", "Team"], how="left")
merged_points_df.head()
# Out:
#    Season  RoundNum RoundName  Day       Date                Winner  \
# 0    2022         1  WildCard  Sat  1/14/2023  Jacksonville Jaguars
# 1    2022         1  WildCard  Sat  1/14/2023   San Francisco 49ers
# 2    2022         1  WildCard  Sun  1/15/2023         Buffalo Bills
# 3    2022         1  WildCard  Sun  1/15/2023    Cincinnati Bengals
# 4    2022         1  WildCard  Sun  1/15/2023       New York Giants
#
#   Unnamed: 6                 Loser Unnamed: 8  PtsWinner  ...  DefRushYards  \
# 0        NaN  Los Angeles Chargers   boxscore         31  ...          1951
# 1        NaN      Seattle Seahawks   boxscore         41  ...          1321
# 2        NaN        Miami Dolphins   boxscore         34  ...          1673
# 3        NaN      Baltimore Ravens   boxscore         24  ...          1706
# 4          @     Minnesota Vikings   boxscore         31  ...          2451
#
#    DefRushTouchdowns DefRushYardsPerAttempt  DefRush1stDowns  \
# 0                 14                    4.2              114
# 1                 11                    3.4               77
# 2                 10                    4.3              103
# 3                 12                    4.2              102
# 4                 16                    5.2              134
#
#    DefNumOfPenalties  DefPenaltyYards  Def1stDownsByPenalty  \
# 0                 90              683                    25
# 1                 96              832                    26
# 2                 89              754                    29
# 3                100              832                    20
# 4                111              819                    36
#
#    DefPctOfDrivesEndingInScore  DefPctOfDrivesEndingInTurnover  \
# 0                         36.1                            14.4
# 1                         25.7                            15.3
# 2                         31.0                            14.3
# 3                         36.4                            13.1
# 4                         39.8                             8.8
#
#    DefExpectedPointsContributed
# 0                        -52.27
# 1                         56.26
# 2                          4.46
# 3                        -20.02
# 4                       -125.22
#
# [5 rows x 66 columns]

# %%
playoff_points_df = merged_points_df[merged_points_df['RoundName'].str.contains('SuperBowl')]

playoff_points_df
# Out:
#      Season  RoundNum  RoundName  Day       Date                Winner  \
# 12     2022         4  SuperBowl  Sun  2/12/2022    Kansas City Chiefs
# 24     2021         4  SuperBowl  Sun  2/13/2022      Los Angeles Rams
# 37     2020         4  SuperBowl  Sun   2/7/2021  Tampa Bay Buccaneers
# 48     2019         4  SuperBowl  Sun   2/2/2020    Kansas City Chiefs
# 59     2018         4  SuperBowl  Sun   2/3/2019  New England Patriots
# 70     2017         4  SuperBowl  Sun   2/4/2018   Philadelphia Eagles
# 81     2016         4  SuperBowl  Sun   2/5/2017  New England Patriots
# 92     2015         4  SuperBowl  Sun   2/7/2016        Denver Broncos
# 103    2014         4  SuperBowl  Sun   2/1/2015  New England Patriots
# 114    2013         4  SuperBowl  Sun   2/2/2014      Seattle Seahawks
# 125    2012         4  SuperBowl  Sun   2/3/2013      Baltimore Ravens
# 136    2011         4  SuperBowl  Sun   2/5/2012       New York Giants
# 147    2010         4  SuperBowl  Sun   2/6/2011     Green Bay Packers
# 158    2009         4  SuperBowl  Sun   2/7/2010    New Orleans Saints
# 169    2008         4  SuperBowl  Sun   2/1/2009   Pittsburgh Steelers
# 180    2007         4  SuperBowl  Sun   2/3/2008       New York Giants
# 191    2006         4  SuperBowl  Sun   2/4/2007    Indianapolis Colts
# 202    2005         4  SuperBowl  Sun   2/5/2006   Pittsburgh Steelers
# 213    2004         4  SuperBowl  Sun   2/6/2005  New England Patriots
# 224    2003         4  SuperBowl  Sun   2/1/2004  New England Patriots
#
#     Unnamed: 6                 Loser Unnamed: 8  PtsWinner  ...  DefRushYards  \
# 12         NaN   Philadelphia Eagles   boxscore         38  ...          1823
# 24           N    Cincinnati Bengals   boxscore         23  ...          1754
# 37           N    Kansas City Chiefs   boxscore         31  ...          1289
# 48           N   San Francisco 49ers   boxscore         31  ...          2051
# 59           N      Los Angeles Rams   boxscore         13  ...          1803
# 70           N  New England Patriots   boxscore         41  ...          1267
# 81           N       Atlanta Falcons   boxscore         34  ...          1417
# 92           N     Carolina Panthers   boxscore         24  ...          1337
# 103          N      Seattle Seahawks   boxscore         28  ...          1669
# 114          N        Denver Broncos   boxscore         43  ...          1626
# 125          N   San Francisco 49ers   boxscore         34  ...          1965
# 136          N  New England Patriots   boxscore         21  ...          1940
# 147          N   Pittsburgh Steelers   boxscore         31  ...          1838
# 158          N    Indianapolis Colts   boxscore         31  ...          1955
# 169          N     Arizona Cardinals   boxscore         27  ...          1284
# 180          N  New England Patriots   boxscore         17  ...          1563
# 191          N         Chicago Bears   boxscore         29  ...          2768
# 202          N      Seattle Seahawks   boxscore         21  ...          1376
# 213          N   Philadelphia Eagles   boxscore         24  ...          1572
# 224          N     Carolina Panthers   boxscore         32  ...          1434
#
#      DefRushTouchdowns DefRushYardsPerAttempt  DefRush1stDowns  \
# 12                  10                    4.4              102
# 24                  18                    4.0              111
# 37                  10                    3.6               78
# 48                  14                    4.9              115
# 59                   7                    4.9               93
# 70                   7                    3.8               62
# 81                   6                    3.9               81
# 92                  10                    3.3               81
# 103                  6                    4.0               88
# 114                  4                    3.9               83
# 125                 15                    4.0              105
# 136                 15                    4.5              103
# 147                  6                    4.7               82
# 158                 19                    4.5              111
# 169                  7                    3.3               73
# 180                 12                    3.8               83
# 191                 20                    5.3              150
# 202                 10                    3.4               75
# 213                  9                    3.9               83
# 224                 10                    3.6               91
#
#      DefNumOfPenalties  DefPenaltyYards  Def1stDownsByPenalty  \
# 12                  98              734                    28
# 24                  88              688                    22
# 37                  95             1015                    26
# 48                 116              844                    39
# 59                  91              838                    21
# 70                 101              917                    33
# 81                 113              930                    23
# 92                 104              773                    46
# 103                 92              752                    45
# 114                 98              879                    43
# 125                107              929                    34
# 136                110              933                    25
# 147                 98              758                    25
# 158                 86              717                    24
# 169                 91              801                    18
# 180                118              874                    20
# 191                 86              667                    25
# 202                120             1031                    21
# 213                118             1014                    30
# 224                107              845                    25
#
#      DefPctOfDrivesEndingInScore  DefPctOfDrivesEndingInTurnover  \
# 12                          35.9                            10.3
# 24                          35.9                            13.3
# 37                          33.7                            14.0
# 48                          34.1                            13.4
# 59                          32.6                            15.0
# 70                          27.1                            15.4
# 81                          26.8                            11.2
# 92                          26.9                            11.9
# 103                         32.4                            13.2
# 114                         24.7                            19.4
# 125                         34.9                            12.0
# 136                         34.7                            14.8
# 147                         25.3                            16.5
# 158                         31.4                            18.0
# 169                         22.9                            14.4
# 180                         29.5                            12.4
# 191                         38.5                            16.7
# 202                         27.1                            14.9
# 213                         24.0                            20.0
# 224                         23.0                            19.5
#
#      DefExpectedPointsContributed
# 12                         -49.50
# 24                         -17.07
# 37                         -22.04
# 48                         -56.69
# 59                         -32.66
# 70                         162.09
# 81                         108.15
# 92                         141.46
# 103                        -51.58
# 114                        129.49
# 125                        132.17
# 136                         57.49
# 147                        199.39
# 158                        178.25
# 169                        308.95
# 180                        126.48
# 191                         93.05
# 202                        268.34
# 213                        244.33
# 224                        280.69
#
# [20 rows x 66 columns]

# %%
playoff_points_df.plot.bar(x='Season', y='OffTotPoints', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffTotYards', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffTotPlaysRun', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffTotYardsPerPlay', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffTotTurnovers', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffTotFumbles', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffTot1stDowns', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffPassCompletions', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffPassAttempts', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffPassYards', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffPassTouchdowns', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffPassInterceptions', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffPassNetYardsPerAttempt', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffPass1stDowns', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffRushAttempts', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffRushYards', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffRushTouchdowns', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffRushYardsPerAttempt', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffRush1stDowns', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffNumOfPenalties', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffPenaltyYards', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='Off1stDownsByPenalty', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffPctOfDrivesEndingInScore', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffPctOfDrivesEndingInTurnover', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='OffExpectedPointsContributed', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefTotPoints', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefTotYards', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefTotPlaysRun', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefTotYardsPerPlay', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefTotTakeaways', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefTotFumbles', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefTot1stDowns', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefPassCompletions', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefPassAttempts', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefPassYards', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefPassTouchdowns', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefPassInterceptions', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefPassNetYardsPerAttempt', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefPass1stDowns', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefRushAttempts', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefRushYards', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefRushTouchdowns', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefRushYardsPerAttempt', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefRush1stDowns', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefNumOfPenalties', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefPenaltyYards', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='Def1stDownsByPenalty', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefPctOfDrivesEndingInScore', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefPctOfDrivesEndingInTurnover', color='red', legend=True)

playoff_points_df.plot.bar(x='Season', y='DefExpectedPointsContributed', color='red', legend=True)
# Out:
# C:\Users\mlech\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:386: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# <AxesSubplot:xlabel='Season'>

# %%
playoff_points_df
# Out:
#      Season  RoundNum  RoundName  Day       Date                Winner  \
# 12     2022         4  SuperBowl  Sun  2/12/2023    Kansas City Chiefs
# 25     2021         4  SuperBowl  Sun  2/13/2022      Los Angeles Rams
# 38     2020         4  SuperBowl  Sun   2/7/2021  Tampa Bay Buccaneers
# 49     2019         4  SuperBowl  Sun   2/2/2020    Kansas City Chiefs
# 60     2018         4  SuperBowl  Sun   2/3/2019  New England Patriots
# 71     2017         4  SuperBowl  Sun   2/4/2018   Philadelphia Eagles
# 82     2016         4  SuperBowl  Sun   2/5/2017  New England Patriots
# 93     2015         4  SuperBowl  Sun   2/7/2016        Denver Broncos
# 104    2014         4  SuperBowl  Sun   2/1/2015  New England Patriots
# 115    2013         4  SuperBowl  Sun   2/2/2014      Seattle Seahawks
# 126    2012         4  SuperBowl  Sun   2/3/2013      Baltimore Ravens
# 137    2011         4  SuperBowl  Sun   2/5/2012       New York Giants
# 148    2010         4  SuperBowl  Sun   2/6/2011     Green Bay Packers
# 159    2009         4  SuperBowl  Sun   2/7/2010    New Orleans Saints
# 170    2008         4  SuperBowl  Sun   2/1/2009   Pittsburgh Steelers
# 181    2007         4  SuperBowl  Sun   2/3/2008       New York Giants
# 192    2006         4  SuperBowl  Sun   2/4/2007    Indianapolis Colts
# 203    2005         4  SuperBowl  Sun   2/5/2006   Pittsburgh Steelers
# 214    2004         4  SuperBowl  Sun   2/6/2005  New England Patriots
# 225    2003         4  SuperBowl  Sun   2/1/2004  New England Patriots
#
#     Unnamed: 6                 Loser Unnamed: 8  PtsWinner  ...  DefRushYards  \
# 12         NaN   Philadelphia Eagles   boxscore         38  ...          1823
# 25           N    Cincinnati Bengals   boxscore         23  ...          1754
# 38           N    Kansas City Chiefs   boxscore         31  ...          1289
# 49           N   San Francisco 49ers   boxscore         31  ...          2051
# 60           N      Los Angeles Rams   boxscore         13  ...          1803
# 71           N  New England Patriots   boxscore         41  ...          1267
# 82           N       Atlanta Falcons   boxscore         34  ...          1417
# 93           N     Carolina Panthers   boxscore         24  ...          1337
# 104          N      Seattle Seahawks   boxscore         28  ...          1669
# 115          N        Denver Broncos   boxscore         43  ...          1626
# 126          N   San Francisco 49ers   boxscore         34  ...          1965
# 137          N  New England Patriots   boxscore         21  ...          1940
# 148          N   Pittsburgh Steelers   boxscore         31  ...          1838
# 159          N    Indianapolis Colts   boxscore         31  ...          1955
# 170          N     Arizona Cardinals   boxscore         27  ...          1284
# 181          N  New England Patriots   boxscore         17  ...          1563
# 192          N         Chicago Bears   boxscore         29  ...          2768
# 203          N      Seattle Seahawks   boxscore         21  ...          1376
# 214          N   Philadelphia Eagles   boxscore         24  ...          1572
# 225          N     Carolina Panthers   boxscore         32  ...          1434
#
#      DefRushTouchdowns DefRushYardsPerAttempt  DefRush1stDowns  \
# 12                  10                    4.4              102
# 25                  18                    4.0              111
# 38                  10                    3.6               78
# 49                  14                    4.9              115
# 60                   7                    4.9               93
# 71                   7                    3.8               62
# 82                   6                    3.9               81
# 93                  10                    3.3               81
# 104                  6                    4.0               88
# 115                  4                    3.9               83
# 126                 15                    4.0              105
# 137                 15                    4.5              103
# 148                  6                    4.7               82
# 159                 19                    4.5              111
# 170                  7                    3.3               73
# 181                 12                    3.8               83
# 192                 20                    5.3              150
# 203                 10                    3.4               75
# 214                  9                    3.9               83
# 225                 10                    3.6               91
#
#      DefNumOfPenalties  DefPenaltyYards  Def1stDownsByPenalty  \
# 12                  98              734                    28
# 25                  88              688                    22
# 38                  95             1015                    26
# 49                 116              844                    39
# 60                  91              838                    21
# 71                 101              917                    33
# 82                 113              930                    23
# 93                 104              773                    46
# 104                 92              752                    45
# 115                 98              879                    43
# 126                107              929                    34
# 137                110              933                    25
# 148                 98              758                    25
# 159                 86              717                    24
# 170                 91              801                    18
# 181                118              874                    20
# 192                 86              667                    25
# 203                120             1031                    21
# 214                118             1014                    30
# 225                107              845                    25
#
#      DefPctOfDrivesEndingInScore  DefPctOfDrivesEndingInTurnover  \
# 12                          35.9                            10.3
# 25                          35.9                            13.3
# 38                          33.7                            14.0
# 49                          34.1                            13.4
# 60                          32.6                            15.0
# 71                          27.1                            15.4
# 82                          26.8                            11.2
# 93                          26.9                            11.9
# 104                         32.4                            13.2
# 115                         24.7                            19.4
# 126                         34.9                            12.0
# 137                         34.7                            14.8
# 148                         25.3                            16.5
# 159                         31.4                            18.0
# 170                         22.9                            14.4
# 181                         29.5                            12.4
# 192                         38.5                            16.7
# 203                         27.1                            14.9
# 214                         24.0                            20.0
# 225                         23.0                            19.5
#
#      DefExpectedPointsContributed
# 12                         -49.50
# 25                         -17.07
# 38                         -22.04
# 49                         -56.69
# 60                         -32.66
# 71                         162.09
# 82                         108.15
# 93                         141.46
# 104                        -51.58
# 115                        129.49
# 126                        132.17
# 137                         57.49
# 148                        199.39
# 159                        178.25
# 170                        308.95
# 181                        126.48
# 192                         93.05
# 203                        268.34
# 214                        244.33
# 225                        280.69
#
# [20 rows x 66 columns]

# %%
for col in playoff_points_df.columns:
    #playoff_points_df[col].plot(kind='bar', title=col)
    print(col)
    #plt.show()
# Out:
# Season
# RoundNum
# RoundName
# Day
# Date
# Winner
# Unnamed: 6
# Loser
# Unnamed: 8
# PtsWinner
# PtsLoser
# OffRank
# Team
# GamesPlayed_x
# OffTotPoints
# OffTotYards
# OffTotPlaysRun
# OffTotYardsPerPlay
# OffTotTurnovers
# OffTotFumbles
# OffTot1stDowns
# OffPassCompletions
# OffPassAttempts
# OffPassYards
# OffPassTouchdowns
# OffPassInterceptions
# OffPassNetYardsPerAttempt
# OffPass1stDowns
# OffRushAttempts
# OffRushYards
# OffRushTouchdowns
# OffRushYardsPerAttempt
# OffRush1stDowns
# OffNumOfPenalties
# OffPenaltyYards
# Off1stDownsByPenalty
# OffPctOfDrivesEndingInScore
# OffPctOfDrivesEndingInTurnover
# OffExpectedPointsContributed
# DefRank
# GamesPlayed_y
# DefTotPoints
# DefTotYards
# DefTotPlaysRun
# DefTotYardsPerPlay
# DefTotTakeaways
# DefTotFumbles
# DefTot1stDowns
# DefPassCompletions
# DefPassAttempts
# DefPassYards
# DefPassTouchdowns
# DefPassInterceptions
# DefPassNetYardsPerAttempt
# DefPass1stDowns
# DefRushAttempts
# DefRushYards
# DefRushTouchdowns
# DefRushYardsPerAttempt
# DefRush1stDowns
# DefNumOfPenalties
# DefPenaltyYards
# Def1stDownsByPenalty
# DefPctOfDrivesEndingInScore
# DefPctOfDrivesEndingInTurnover
# DefExpectedPointsContributed

# %%
print(f"Offense count: {len(offense_df)}")
print(f"Defense count: {len(defense_df)}")
print(f"Merge count: {len(reg_season_df)}")
# Out:
# Offense count: 640
# Defense count: 640
# Merge count: 640

# %%
# view new df cols
reg_season_df.columns
# Out:
# Index(['Season', 'OffRank', 'Team', 'GamesPlayed_x', 'OffTotPoints',
#        'OffTotYards', 'OffTotPlaysRun', 'OffTotYardsPerPlay',
#        'OffTotTurnovers', 'OffTotFumbles', 'OffTot1stDowns',
#        'OffPassCompletions', 'OffPassAttempts', 'OffPassYards',
#        'OffPassTouchdowns', 'OffPassInterceptions',
#        'OffPassNetYardsPerAttempt', 'OffPass1stDowns', 'OffRushAttempts',
#        'OffRushYards', 'OffRushTouchdowns', 'OffRushYardsPerAttempt',
#        'OffRush1stDowns', 'OffNumOfPenalties', 'OffPenaltyYards',
#        'Off1stDownsByPenalty', 'OffPctOfDrivesEndingInScore',
#        'OffPctOfDrivesEndingInTurnover', 'OffExpectedPointsContributed',
#        'DefRank', 'GamesPlayed_y', 'DefTotPoints', 'DefTotYards',
#        'DefTotPlaysRun', 'DefTotYardsPerPlay', 'DefTotTakeaways',
#        'DefTotFumbles', 'DefTot1stDowns', 'DefPassCompletions',
#        'DefPassAttempts', 'DefPassYards', 'DefPassTouchdowns',
#        'DefPassInterceptions', 'DefPassNetYardsPerAttempt', 'DefPass1stDowns',
#        'DefRushAttempts', 'DefRushYards', 'DefRushTouchdowns',
#        'DefRushYardsPerAttempt', 'DefRush1stDowns', 'DefNumOfPenalties',
#        'DefPenaltyYards', 'Def1stDownsByPenalty',
#        'DefPctOfDrivesEndingInScore', 'DefPctOfDrivesEndingInTurnover',
#        'DefExpectedPointsContributed'],
#       dtype='object')

# %%
# delete 2 cols we will re-create ourselves to ensure accuracy, delete 1 duplicate column
del reg_season_df["OffRank"]
del reg_season_df["DefRank"]
del reg_season_df["GamesPlayed_y"]

# reformat the other dup
reg_season_df.rename(columns={"GamesPlayed_x": "GamesPlayed"}, inplace=True)
#                               "OffPctOfDrivefEndingInScore": "OffPctOfDrivesEndingInScore"}, inplace=True)

# %%
# verify column name changes
reg_season_df.columns
# Out:
# Index(['Season', 'Team', 'GamesPlayed', 'OffTotPoints', 'OffTotYards',
#        'OffTotPlaysRun', 'OffTotYardsPerPlay', 'OffTotTurnovers',
#        'OffTotFumbles', 'OffTot1stDowns', 'OffPassCompletions',
#        'OffPassAttempts', 'OffPassYards', 'OffPassTouchdowns',
#        'OffPassInterceptions', 'OffPassNetYardsPerAttempt', 'OffPass1stDowns',
#        'OffRushAttempts', 'OffRushYards', 'OffRushTouchdowns',
#        'OffRushYardsPerAttempt', 'OffRush1stDowns', 'OffNumOfPenalties',
#        'OffPenaltyYards', 'Off1stDownsByPenalty',
#        'OffPctOfDrivesEndingInScore', 'OffPctOfDrivesEndingInTurnover',
#        'OffExpectedPointsContributed', 'DefTotPoints', 'DefTotYards',
#        'DefTotPlaysRun', 'DefTotYardsPerPlay', 'DefTotTakeaways',
#        'DefTotFumbles', 'DefTot1stDowns', 'DefPassCompletions',
#        'DefPassAttempts', 'DefPassYards', 'DefPassTouchdowns',
#        'DefPassInterceptions', 'DefPassNetYardsPerAttempt', 'DefPass1stDowns',
#        'DefRushAttempts', 'DefRushYards', 'DefRushTouchdowns',
#        'DefRushYardsPerAttempt', 'DefRush1stDowns', 'DefNumOfPenalties',
#        'DefPenaltyYards', 'Def1stDownsByPenalty',
#        'DefPctOfDrivesEndingInScore', 'DefPctOfDrivesEndingInTurnover',
#        'DefExpectedPointsContributed'],
#       dtype='object')

# %%
reg_point_df = reg_season_df

# %%
# for both offense and defense, group by each seasosn and create new rank columns for total yards
reg_season_df["OffTotPointsRank"] = reg_season_df.groupby("Season")["OffTotPoints"].rank(ascending=False).astype(int)
reg_season_df["OffTotYardsRank"] = reg_season_df.groupby("Season")["OffTotYards"].rank(ascending=False).astype(int)
reg_season_df["OffTotPlaysRunRank"] = reg_season_df.groupby("Season")["OffTotPlaysRun"].rank(ascending=False).astype(int)
reg_season_df["OffTotYardsPerPlayRank"] = reg_season_df.groupby("Season")["OffTotYardsPerPlay"].rank(ascending=False).astype(int)
reg_season_df["OffTotTurnoversRank"] = reg_season_df.groupby("Season")["OffTotTurnovers"].rank(ascending=False).astype(int)
reg_season_df["OffTotFumblesRank"] = reg_season_df.groupby("Season")["OffTotFumbles"].rank(ascending=False).astype(int)
reg_season_df["OffTot1stDownsRank"] = reg_season_df.groupby("Season")["OffTot1stDowns"].rank(ascending=False).astype(int)
reg_season_df["OffPassCompletionsRank"] = reg_season_df.groupby("Season")["OffPassCompletions"].rank(ascending=False).astype(int)
reg_season_df["OffPassAttemptsRank"] = reg_season_df.groupby("Season")["OffPassAttempts"].rank(ascending=False).astype(int)
reg_season_df["OffPassYardsRank"] = reg_season_df.groupby("Season")["OffPassYards"].rank(ascending=False).astype(int)
reg_season_df["OffPassTouchdownsRank"] = reg_season_df.groupby("Season")["OffPassTouchdowns"].rank(ascending=False).astype(int)
reg_season_df["OffPassInterceptionsRank"] = reg_season_df.groupby("Season")["OffPassInterceptions"].rank(ascending=False).astype(int)
reg_season_df["OffPassNetYardsPerAttemptRank"] = reg_season_df.groupby("Season")["OffPassNetYardsPerAttempt"].rank(ascending=False).astype(int)
reg_season_df["OffPass1stDownsRank"] = reg_season_df.groupby("Season")["OffPass1stDowns"].rank(ascending=False).astype(int)
reg_season_df["OffRushAttemptsRank"] = reg_season_df.groupby("Season")["OffRushAttempts"].rank(ascending=False).astype(int)
reg_season_df["OffRushYardsRank"] = reg_season_df.groupby("Season")["OffRushYards"].rank(ascending=False).astype(int)
reg_season_df["OffRushTouchdownsRank"] = reg_season_df.groupby("Season")["OffRushTouchdowns"].rank(ascending=False).astype(int)
reg_season_df["OffRushYardsPerAttemptRank"] = reg_season_df.groupby("Season")["OffRushYardsPerAttempt"].rank(ascending=False).astype(int)
reg_season_df["OffRush1stDownsRank"] = reg_season_df.groupby("Season")["OffRush1stDowns"].rank(ascending=False).astype(int)
reg_season_df["OffNumOfPenaltiesRank"] = reg_season_df.groupby("Season")["OffNumOfPenalties"].rank(ascending=False).astype(int)
reg_season_df["OffPenaltyYardsRank"] = reg_season_df.groupby("Season")["OffPenaltyYards"].rank(ascending=False).astype(int)
reg_season_df["Off1stDownsByPenaltyRank"] = reg_season_df.groupby("Season")["Off1stDownsByPenalty"].rank(ascending=False).astype(int)
reg_season_df["OffPctOfDrivesEndingInScoreRank"] = reg_season_df.groupby("Season")["OffPctOfDrivesEndingInScore"].rank(ascending=False).astype(int)
reg_season_df["OffPctOfDrivesEndingInTurnoverRank"] = reg_season_df.groupby("Season")["OffPctOfDrivesEndingInTurnover"].rank(ascending=False).astype(int)
reg_season_df["OffExpectedPointsContributedRank"] = reg_season_df.groupby("Season")["OffExpectedPointsContributed"].rank(ascending=False).astype(int)
reg_season_df["DefTotPointsRank"] = reg_season_df.groupby("Season")["DefTotPoints"].rank(ascending=True).astype(int)
reg_season_df["DefTotYardsRank"] = reg_season_df.groupby("Season")["DefTotYards"].rank(ascending=True).astype(int)
reg_season_df["DefTotPlaysRunRank"] = reg_season_df.groupby("Season")["DefTotPlaysRun"].rank(ascending=True).astype(int)
reg_season_df["DefTotYardsPerPlayRank"] = reg_season_df.groupby("Season")["DefTotYardsPerPlay"].rank(ascending=True).astype(int)
reg_season_df["DefTotTakeawaysRank"] = reg_season_df.groupby("Season")["DefTotTakeaways"].rank(ascending=True).astype(int)
reg_season_df["DefTotFumblesRank"] = reg_season_df.groupby("Season")["DefTotFumbles"].rank(ascending=True).astype(int)
reg_season_df["DefTot1stDownsRank"] = reg_season_df.groupby("Season")["DefTot1stDowns"].rank(ascending=True).astype(int)
reg_season_df["DefPassCompletionsRank"] = reg_season_df.groupby("Season")["DefPassCompletions"].rank(ascending=True).astype(int)
reg_season_df["DefPassAttemptsRank"] = reg_season_df.groupby("Season")["DefPassAttempts"].rank(ascending=True).astype(int)
reg_season_df["DefPassYardsRank"] = reg_season_df.groupby("Season")["DefPassYards"].rank(ascending=True).astype(int)
reg_season_df["DefPassTouchdownsRank"] = reg_season_df.groupby("Season")["DefPassTouchdowns"].rank(ascending=True).astype(int)
reg_season_df["DefPassInterceptionsRank"] = reg_season_df.groupby("Season")["DefPassInterceptions"].rank(ascending=True).astype(int)
reg_season_df["DefPassNetYardsPerAttemptRank"] = reg_season_df.groupby("Season")["DefPassNetYardsPerAttempt"].rank(ascending=True).astype(int)
reg_season_df["DefPass1stDownsRank"] = reg_season_df.groupby("Season")["DefPass1stDowns"].rank(ascending=True).astype(int)
reg_season_df["DefRushAttemptsRank"] = reg_season_df.groupby("Season")["DefRushAttempts"].rank(ascending=True).astype(int)
reg_season_df["DefRushYardsRank"] = reg_season_df.groupby("Season")["DefRushYards"].rank(ascending=True).astype(int)
reg_season_df["DefRushTouchdownsRank"] = reg_season_df.groupby("Season")["DefRushTouchdowns"].rank(ascending=True).astype(int)
reg_season_df["DefRushYardsPerAttemptRank"] = reg_season_df.groupby("Season")["DefRushYardsPerAttempt"].rank(ascending=True).astype(int)
reg_season_df["DefRush1stDownsRank"] = reg_season_df.groupby("Season")["DefRush1stDowns"].rank(ascending=True).astype(int)
reg_season_df["DefNumOfPenaltiesRank"] = reg_season_df.groupby("Season")["DefNumOfPenalties"].rank(ascending=True).astype(int)
reg_season_df["DefPenaltyYardsRank"] = reg_season_df.groupby("Season")["DefPenaltyYards"].rank(ascending=True).astype(int)
reg_season_df["Def1stDownsByPenaltyRank"] = reg_season_df.groupby("Season")["Def1stDownsByPenalty"].rank(ascending=True).astype(int)
reg_season_df["DefPctOfDrivesEndingInScoreRank"] = reg_season_df.groupby("Season")["DefPctOfDrivesEndingInScore"].rank(ascending=True).astype(int)
reg_season_df["DefPctOfDrivesEndingInTurnoverRank"] = reg_season_df.groupby("Season")["DefPctOfDrivesEndingInTurnover"].rank(ascending=True).astype(int)
reg_season_df["DefExpectedPointsContributedRank"] = reg_season_df.groupby("Season")["DefExpectedPointsContributed"].rank(ascending=True).astype(int)

# %%
reg_season_df.head(34)
# Out:
#     Season                   Team  GamesPlayed  OffTotPoints  OffTotYards  \
# 0     2022     Kansas City Chiefs           17           496         7032
# 1     2022    Philadelphia Eagles           17           477         6614
# 2     2022         Dallas Cowboys           17           467         6034
# 3     2022          Buffalo Bills           16           455         6361
# 4     2022          Detroit Lions           17           453         6460
# 5     2022    San Francisco 49ers           17           450         6216
# 6     2022      Minnesota Vikings           17           424         6145
# 7     2022     Cincinnati Bengals           16           418         5768
# 8     2022       Seattle Seahawks           17           407         5976
# 9     2022   Jacksonville Jaguars           17           404         6075
# 10    2022         Miami Dolphins           17           397         6197
# 11    2022      Las Vegas Raiders           17           395         5993
# 12    2022   Los Angeles Chargers           17           391         6108
# 13    2022      Green Bay Packers           17           370         5745
# 14    2022        Atlanta Falcons           17           365         5417
# 15    2022        New York Giants           17           365         5676
# 16    2022   New England Patriots           17           364         5348
# 17    2022       Cleveland Browns           17           361         5934
# 18    2022       Baltimore Ravens           17           350         5760
# 19    2022      Carolina Panthers           17           347         5206
# 20    2022      Arizona Cardinals           17           340         5499
# 21    2022     New Orleans Saints           17           330         5674
# 22    2022          Chicago Bears           17           326         5233
# 23    2022  Washington Commanders           17           321         5615
# 24    2022   Tampa Bay Buccaneers           17           313         5894
# 25    2022    Pittsburgh Steelers           17           308         5484
# 26    2022       Los Angeles Rams           17           307         4769
# 27    2022       Tennessee Titans           17           298         5045
# 28    2022          New York Jets           17           296         5409
# 29    2022         Houston Texans           17           289         4820
# 30    2022     Indianapolis Colts           17           289         5298
# 31    2022         Denver Broncos           17           287         5527
# 32    2021         Dallas Cowboys           17           530         6919
# 33    2021   Tampa Bay Buccaneers           17           511         6901
#
#     OffTotPlaysRun  OffTotYardsPerPlay  OffTotTurnovers  OffTotFumbles  \
# 0             1094                 6.4               23             11
# 1             1124                 5.9               19             10
# 2             1114                 5.4               23              5
# 3             1037                 6.1               27             13
# 4             1092                 5.9               15              8
# 5             1047                 5.9               17              8
# 6             1123                 5.5               23              8
# 7             1053                 5.5               18              6
# 8             1044                 5.7               23             11
# 9             1072                 5.7               22             13
# 10            1009                 6.1               21              6
# 11            1049                 5.7               21              4
# 12            1154                 5.3               19              9
# 13            1051                 5.5               22             10
# 14            1011                 5.4               21             12
# 15            1089                 5.2               16             10
# 16            1006                 5.3               23              9
# 17            1116                 5.3               21              9
# 18            1052                 5.5               21              8
# 19             976                 5.3               21              8
# 20            1144                 4.8               25              8
# 21            1015                 5.6               25             11
# 22             993                 5.3               25             10
# 23            1140                 4.9               23              7
# 24            1159                 5.1               22             12
# 25            1109                 4.9               19              5
# 26            1001                 4.8               23              8
# 27             992                 5.1               23             12
# 28            1074                 5.0               23              9
# 29            1015                 4.7               28              9
# 30            1103                 4.8               34             14
# 31            1078                 5.1               24              9
# 32            1153                 6.0               20              9
# 33            1139                 6.1               19              7
#
#     OffTot1stDowns  ...  DefRushYardsRank  DefRushTouchdownsRank  \
# 0              408  ...                 8                      6
# 1              385  ...                16                     18
# 2              347  ...                22                      3
# 3              367  ...                 4                      6
# 4              376  ...                29                     29
# 5              347  ...                 2                      8
# 6              382  ...                20                     23
# 7              357  ...                 5                     11
# 8              346  ...                30                     27
# 9              352  ...                12                     15
# 10             342  ...                 6                     18
# 11             343  ...                19                     25
# 12             352  ...                28                     21
# 13             334  ...                26                     23
# 14             330  ...                23                     18
# 15             352  ...                27                     20
# 16             288  ...                 7                      1
# 17             350  ...                25                     29
# 18             337  ...                 3                      8
# 19             281  ...                18                     21
# 20             326  ...                14                     27
# 21             305  ...                24                     15
# 22             278  ...                31                     32
# 23             339  ...                11                      6
# 24             346  ...                15                     11
# 25             345  ...                 9                      1
# 26             293  ...                13                     11
# 27             277  ...                 1                      3
# 28             294  ...                16                     15
# 29             277  ...                32                     31
# 30             310  ...                21                     25
# 31             300  ...                10                     11
# 32             390  ...                16                      8
# 33             404  ...                 3                      5
#
#     DefRushYardsPerAttemptRank  DefRush1stDownsRank  DefNumOfPenaltiesRank  \
# 0                           16                    8                     22
# 1                           24                   16                     16
# 2                           16                   18                     22
# 3                           12                   10                      9
# 4                           30                   29                     27
# 5                            1                    1                     18
# 6                           21                   14                     30
# 7                            8                    8                     25
# 8                           26                   27                     22
# 9                            8                   15                     11
# 10                           5                    6                      4
# 11                          21                   23                     14
# 12                          32                   18                      2
# 13                          28                   25                     25
# 14                          16                   30                     25
# 15                          30                   28                     30
# 16                           5                    2                      9
# 17                          25                   25                      7
# 18                           3                    3                      1
# 19                          12                   22                     28
# 20                          21                   21                     15
# 21                          21                   20                     13
# 22                          26                   32                      4
# 23                          16                    8                      6
# 24                          21                   10                     20
# 25                           8                    5                     18
# 26                          12                   12                      3
# 27                           1                    4                     32
# 28                           8                   17                     11
# 29                          29                   31                     16
# 30                           5                   24                      9
# 31                          12                   13                     29
# 32                          23                    6                     31
# 33                          15                    4                      1
#
#     DefPenaltyYardsRank  Def1stDownsByPenaltyRank  \
# 0                    11                        17
# 1                    17                         7
# 2                    27                        27
# 3                    12                        20
# 4                    21                        25
# 5                    24                        12
# 6                    32                         4
# 7                    24                         2
# 8                    21                        20
# 9                     3                         9
# 10                   19                        31
# 11                   14                        17
# 12                   15                         7
# 13                   30                        20
# 14                   20                         1
# 15                   23                        30
# 16                    5                        23
# 17                    8                        27
# 18                    2                        12
# 19                   29                        15
# 20                   13                         3
# 21                   17                        31
# 22                    1                        12
# 23                    6                        20
# 24                   28                         9
# 25                    9                         6
# 26                    4                         4
# 27                   26                        24
# 28                    6                        15
# 29                   16                        12
# 30                   10                        25
# 31                   31                        29
# 32                   27                        26
# 33                    1                        24
#
#     DefPctOfDrivesEndingInScoreRank  DefPctOfDrivesEndingInTurnoverRank  \
# 0                                14                                  12
# 1                                 6                                  30
# 2                                 8                                  32
# 3                                 3                                  28
# 4                                29                                  18
# 5                                 1                                  31
# 6                                28                                  20
# 7                                18                                  24
# 8                                19                                  22
# 9                                17                                  29
# 10                               22                                   3
# 11                               26                                   2
# 12                               19                                  16
# 13                               23                                  25
# 14                               32                                   8
# 15                               25                                   7
# 16                                2                                  27
# 17                               24                                  10
# 18                               13                                  25
# 19                               10                                   5
# 20                               30                                  13
# 21                               11                                   1
# 22                               31                                  18
# 23                                4                                   3
# 24                                7                                  10
# 25                               21                                  23
# 26                               27                                  21
# 27                                9                                  14
# 28                                5                                   5
# 29                               12                                  18
# 30                               16                                  10
# 31                               14                                  14
# 32                                4                                  30
# 33                                6                                  27
#
#     DefExpectedPointsContributedRank
# 0                                 19
# 1                                 30
# 2                                 29
# 3                                 25
# 4                                  2
# 5                                 32
# 6                                  7
# 7                                 24
# 8                                  6
# 9                                 15
# 10                                12
# 11                                 3
# 12                                 8
# 13                                13
# 14                                 5
# 15                                 4
# 16                                31
# 17                                14
# 18                                22
# 19                                17
# 20                                 9
# 21                                23
# 22                                 1
# 23                                27
# 24                                21
# 25                                20
# 26                                11
# 27                                16
# 28                                28
# 29                                10
# 30                                18
# 31                                26
# 32                                30
# 33                                29
#
# [34 rows x 103 columns]

# %%
# create new df for total yards rankings by season
reg_season_rankings_df = reg_season_df[["Season", \
                              "Team", \
                              "OffTotPointsRank", \
                              "DefTotPointsRank", \
                              "OffTotYardsRank", \
                              "DefTotYardsRank", \
                              "OffTotPlaysRunRank", \
                              "DefTotPlaysRunRank", \
                              "OffTotYardsPerPlayRank", \
                              "DefTotYardsPerPlayRank", \
                              "OffTotTurnoversRank", \
                              "DefTotTakeawaysRank", \
                              "OffTotFumblesRank", \
                              "DefTotFumblesRank", \
                              "OffTot1stDownsRank", \
                              "DefTot1stDownsRank", \
                              "OffPassCompletionsRank", \
                              "DefPassCompletionsRank", \
                              "OffPassAttemptsRank", \
                              "DefPassAttemptsRank", \
                              "OffPassYardsRank", \
                              "DefPassYardsRank", \
                              "OffPassTouchdownsRank", \
                              "DefPassTouchdownsRank", \
                              "OffPassInterceptionsRank", \
                              "DefPassInterceptionsRank", \
                              "OffPassNetYardsPerAttemptRank", \
                              "DefPassNetYardsPerAttemptRank", \
                              "OffPass1stDownsRank", \
                              "DefPass1stDownsRank", \
                              "OffRushAttemptsRank", \
                              "DefRushAttemptsRank", \
                              "OffRushYardsRank", \
                              "DefRushYardsRank", \
                              "OffRushTouchdownsRank", \
                              "DefRushTouchdownsRank", \
                              "OffRushYardsPerAttemptRank", \
                              "DefRushYardsPerAttemptRank", \
                              "OffRush1stDownsRank", \
                              "DefRush1stDownsRank", \
                              "OffNumOfPenaltiesRank", \
                              "DefNumOfPenaltiesRank", \
                              "OffPenaltyYardsRank", \
                              "DefPenaltyYardsRank", \
                              "Off1stDownsByPenaltyRank", \
                              "Def1stDownsByPenaltyRank", \
                              "OffPctOfDrivesEndingInScoreRank", \
                              "DefPctOfDrivesEndingInScoreRank", \
                              "OffPctOfDrivesEndingInTurnoverRank", \
                              "DefPctOfDrivesEndingInTurnoverRank", \
                              "OffExpectedPointsContributedRank", \
                              "DefExpectedPointsContributedRank" \
                             ]].copy()
# sort the df
reg_season_rankings_df = reg_season_rankings_df.sort_values(by=["Season", "Team"], ascending=True)
reg_season_rankings_df.head(32)

# %%
reg_season_rankings_df.columns

# %%
merged_df = pd.merge(playoff_df, reg_season_rankings_df, left_on=["Season", "Winner"], right_on=["Season", "Team"], how="left")
merged_df.head()

# %%
for col in merged_df.columns:
    if col.startswith("Off"):
        merged_df[col].fillna(0, inplace=True)
        merged_df[col] = merged_df[col].astype('int64')
for col in merged_df.columns:
    if col.startswith("Def"):
        merged_df[col].fillna(0, inplace=True)
        merged_df[col] = merged_df[col].astype('int64')
        
        
merged_df.head()

# %%
filtered_df = merged_df[merged_df['RoundName'].str.contains('SuperBowl')]

filtered_df

# %%
filtered_df.plot.bar(x='Season', y='OffTotYardsRank', color='red', legend=True)

# %%
import matplotlib.pyplot as plt

filtered_df.plot.bar(x='Season', y= "DefTotPointsRank", color='red', legend=True)

# %%
import os
if not os.path.exists('NFL_Playoff_Analysis'):
    os.makedirs('NFL_Playoff_Analysis')
merged_df.to_csv('NFL_Playoff_Analysis/playoff_data.csv', index=False)
